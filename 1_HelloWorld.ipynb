# %% [markdown]
# <a href="https://colab.research.google.com/github/kingpric/Tensorflow_Tutorial/blob/main/1_HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
model = tf.keras.Sequential(layers=[keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(x=xs, y=ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 661ms/step - loss: 81.6257
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 64.2222
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 50.5299
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 39.7574
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 31.2821
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 24.6141
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 19.3679
# Epoch 8/500
# 1/1 [==============================] - 0s 15ms/step - loss: 15.2404
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 11.9931
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.4381
# Epoch 11/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.4280
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 175ms/step
# [[30.997932]]
